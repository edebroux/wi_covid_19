# %% [markdown]
# ### Wisconsin Coronavirus Data Analysis-Statewide Data
# We are here once again to look at the coronavirus data for the state of Wisconsin. Since the beginning of the academic year for the school age children, the number of COVID-SARS 19 cases in the state of Wisconsin has risen significantly along with other Midwestern states, worrying public health officials and some state politicians alike. With that in mind, I want to revisit the coronavirus data the Wisconsin Department of Health Services has provided that dates back to mid-March. If we have time, I will try to apply a model that utilizes a system of differential equations to predict how we may look in the future.

# %%
# Import the Python packages necessary for performing this analysis
import os                           # Module for working with the operating system
import numpy as np                  # Module for performing mathematical operations
import pandas as pd                 # Module for manipulating tabular data
import matplotlib.pyplot as plt     # Module for plotting data
import warnings                     # Module for handling warnings that arise when running Python code

# Hiding warnings from imports of Python modules
warnings.filterwarnings("ignore")

# %% [markdown]
# We need to load the datasets into the folder, first the statewide dataset.

# %%
# Change the working directory to allow access to the datasets
print("The current working directory of this script is" + os.getcwd() + "\n")

try:
    os.chdir("C:/Users/debro/OneDrive/Documents/Codes_and_Data/coding_projects/WI_Coronavirus_Study")
    print("The current working directory is: " + os.getcwd() + ". You successfully changed the working directory.")
except OSError:
    print("The working directory was not successfully changed.")
# Out:
# The current working directory of this script isC:\Users\debro\OneDrive\Documents\Codes_and_Data\coding_projects\WI_Coronavirus_Study\analysis_scripts
#
# The current working directory is: C:\Users\debro\OneDrive\Documents\Codes_and_Data\coding_projects\WI_Coronavirus_Study. You successfully changed the working directory.

# %%
# Load the dataset from the datasets folder
state_data = pd.read_csv("./wisconsin_data/10012020/wisconsin_covid_19_data.csv", encoding = "utf-8")
state_data = state_data.loc[state_data["NAME"] == "WI"].sort_values(by = "POSITIVE").reset_index()
state_data = state_data.iloc[:, 2:]
# View the first five rows of the statewide dataset
state_data.head()
# Out:
#    GEOID    GEO NAME  NEGATIVE  POSITIVE  HOSP_YES  HOSP_NO  HOSP_UNK  \
# 0     55  State   WI       313        32       NaN      NaN       NaN
# 1     55  State   WI       504        47       NaN      NaN       NaN
# 2     55  State   WI      1038        72       NaN      NaN       NaN
# 3     55  State   WI      1577       106       NaN      NaN       NaN
# 4     55  State   WI      2192       155       NaN      NaN       NaN
#
#    POS_FEM  POS_MALE  ...  DTH_E_NHSP  DTH_E_UNK  POS_HC_Y  POS_HC_N  \
# 0      NaN       NaN  ...         NaN        NaN       NaN       NaN
# 1      NaN       NaN  ...         NaN        NaN       NaN       NaN
# 2      NaN       NaN  ...         NaN        NaN       NaN       NaN
# 3      NaN       NaN  ...         NaN        NaN       NaN       NaN
# 4      NaN       NaN  ...         NaN        NaN       NaN       NaN
#
#    POS_HC_UNK  DTH_NEW  POS_NEW  NEG_NEW  TEST_NEW                    DATE
# ...

# %% [markdown]
# We want to plot the dataset information. We want to do a few things here:
#
# - Plot the cummulative tests, cummulative positive and negative case counts, and cummulative death counts.
# - Plot the 7-day moving average for these same statistics, as most coronavirus cases have a lag between when the disease is contracted and when they test positive
# - Plot the daily positive COVID-19 test rate percentage.

# %%
def plt_covid_cum(dates, num_pos, num_neg, num_dth):
    plt.figure(figsize = (12, 8))
    ax = plt.subplot()
    # Plot the number of tests, positive tests, and deaths
    plt.plot(range(len(dates)), num_pos + num_neg, color = "blue", linewidth = 2,
            label = "Number of Tests")
    plt.plot(range(len(dates)), num_pos, color = "red", linewidth = 2,
            label = "Number of Positive Tests")
    #plt.plot(range(len(dates)), num_neg, color = "green", linewidth = 2,
    #        label = Number of Negative Tests")
    plt.plot(range(len(dates)), num_dth, color = "black", linewidth = 2,
            label = "Number of Deaths from COVID-19")
    plt.title("Wisconsin Cummulative COVID-19 Counts")
    # Annotate certain key dates in the Wisconsin COVID-19 timeline
    # First date Wisconsin DHS creates a dashboard tracking cases
    plt.annotate("1",
                 xy = (0, num_pos[0]),
                 xytext = (0, num_pos[0] + 200000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All gatherings of more than 10 people banned
    plt.annotate("2",
                 xy = (2, num_pos[2]),
                 xytext = (2, num_pos[2] + 200000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All state schools close, March 18th
    plt.annotate("3",
                 xy = (5, num_pos[3]),
                 xytext = (5, num_pos[3] + 200000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All non-essential businesses are ordered to close, March 24th
    plt.annotate("4",
                xy = (8, num_pos[8]),
                xytext = (8, num_pos[8] + 200000),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order extended to May 26th, April 16th
    plt.annotate("5",
                xy = (31, num_pos[31]),
                xytext = (31, num_pos[31] + 200000),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Anti-lockdown protests at State Capitol, April 24th
    plt.annotate("6",
                 xy = (39, num_pos[39]),
                 xytext = (39, num_pos[39] + 200000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order struck down by Wisconsin Supreme Court, May 13th
    plt.annotate("7",
                 xy = (57, num_pos[57]),
                 xytext = (57, num_pos[57] + 200000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # George Floyd is killed by MPLS Police, May 25th
    plt.annotate("8",
                xy = (70, num_pos[70]),
                xytext = (70, num_pos[70] + 200000),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # July 4th
    plt.annotate("9",
                 xy = (110, num_pos[110]),
                 xytext = (110, num_pos[110] + 200000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Governor Evers declares public health emergency requiring masks to be worn
    # in enclosed spaces outside private residences, July 30th
    plt.annotate("10",
                 xy = (136, num_pos[136]),
                 xytext = (136, num_pos[136] + 200000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Labor Day, September 7th. Public schools to start class or are entering their second week
    plt.annotate("11",
                xy = (175, num_pos[175]),
                xytext = (175, num_pos[175] + 200000),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    
    plt.xlabel("Date")
    plt.ylabel("Number of Cases")
    plt.legend()
    ax.set_xticks(range(len(dates)))
    ax.set_xticklabels(dates)
    # TO-DO: add xticks for every week
    for idx, lbl in enumerate(ax.get_xticklabels()):
        if idx % 14 != 0:
            lbl.set_visible(False)
    # Make xticks more easily visible
    plt.xticks(rotation = 300)
    
def plt_positive_percentage(dates, new_pos, new_tests):
    plt.figure(figsize = (12, 8))
    percent_pos = (np.array(new_pos).astype(float) / (np.array(new_tests).astype(float))) * 100.
    percent_pos[0] = (32. / (32. + 313.)) * 100.
    # Creating a 7-day moving average calculation to write over the graphic
    seven_day_pos = []
    seven_day_tst = []
    # Basic loop to calculate the 7-day moving average
    for i in range(len(new_tests) - 6):
        day_pos = np.sum(new_pos[i:(i+7)]) / 7.
        day_tst = np.sum(new_tests[i:(i+7)]) / 7.
        seven_day_pos.append(day_pos)
        seven_day_tst.append(day_tst)
    # Print the seven day moving average of positive cases
    #print(seven_day_pos, seven_day_tst)
    # Calculating the 7-day moving average positive test percentage rate
    seven_ma_percent_pos = (np.array(seven_day_pos).astype(float) / np.array(seven_day_tst).astype(float)) * 100.
    ax = plt.subplot()
    plt.plot(range(len(dates)), percent_pos, color = "red",
             linewidth = 2, label = "Daily Percent of Positive Tests")
    plt.plot(range(6, len(dates)), seven_ma_percent_pos, color = "darkgreen",
             linewidth = 2, label = "7-day Moving Average Percent of Positive Tests")
    plt.ylim(-20, 35)
    # Annotate certain key dates in the Wisconsin COVID-19 timeline
    # First date Wisconsin DHS creates a dashboard tracking cases
    plt.annotate("1",
                 xy = (0, percent_pos[0]),
                 xytext = (0, percent_pos[0] + 10),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All gatherings of more than 10 people banned
    plt.annotate("2",
                 xy = (2, percent_pos[2]),
                 xytext = (2, percent_pos[2] + 10),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All state schools close, March 18th
    plt.annotate("3",
                 xy = (5, percent_pos[3]),
                 xytext = (5, percent_pos[3] + 10),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All non-essential businesses are ordered to close, March 24th
    plt.annotate("4",
                xy = (8, percent_pos[4]),
                xytext = (8, percent_pos[4] + 10),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # State deletes all non-Wisconsin resident tests from their dashboard
    plt.annotate("5",
                xy = (15, percent_pos[15]),
                xytext = (15, percent_pos[15] + 10),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order extended to May 26th, April 16th
    plt.annotate("6",
                xy = (31, percent_pos[31]),
                xytext = (31, percent_pos[31] + 10),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Anti-lockdown protests at State Capitol, April 24th
    plt.annotate("7",
                 xy = (39, percent_pos[39]),
                 xytext = (39, percent_pos[39] + 10),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order struck down by Wisconsin Supreme Court, May 13th
    plt.annotate("8",
                 xy = (57, percent_pos[57]),
                 xytext = (57, percent_pos[57] + 10),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # George Floyd is killed by MPLS Police, May 25th
    plt.annotate("9",
                xy = (70, percent_pos[70]),
                xytext = (70, percent_pos[70] + 10),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # July 4th
    plt.annotate("10",
                 xy = (110, percent_pos[110]),
                 xytext = (110, percent_pos[110] + 10),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Governor Evers declares public health emergency requiring masks to be worn
    # in enclosed spaces outside private residences, July 30th
    plt.annotate("11",
                 xy = (136, percent_pos[136]),
                 xytext = (136, percent_pos[136] + 10),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Labor Day, September 7th. Public schools to start class or are entering their second week
    plt.annotate("12",
                xy = (175, percent_pos[175]),
                xytext = (175, percent_pos[175] + 10),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    plt.title("Wisconsin COVID-19 Percentages")
    plt.xlabel("Date")
    plt.ylabel("Percentage")
    plt.legend()
    ax.set_xticks(range(len(dates)))
    ax.set_xticklabels(dates)
    # TO-DO: add xticks for every week
    for idx, lbl in enumerate(ax.get_xticklabels()):
        if idx % 14 != 0:
            lbl.set_visible(False)
    plt.xticks(rotation = 300)

# THIS NEEDS A REWRITE
def plt_seven_day(dates, new_pos, new_tests, new_dth):
    seven_day_pos = []
    seven_day_tst = []
    seven_day_dth = []
    
    # Basic loop to calculate the 7-day moving average
    for i in range(len(new_tests) - 6):
        day_pos = np.sum(new_pos[i:(i+7)]) / 7.
        day_tst = np.sum(new_tests[i:(i+7)]) / 7.
        day_dth = np.sum(new_dth[i:(i+7)]) / 7.
        seven_day_pos.append(day_pos)
        seven_day_tst.append(day_tst)
        seven_day_dth.append(day_dth)
        
    plt.figure(figsize = (12, 8))
    ax = plt.subplot()
    plt.plot(range(len(seven_day_tst)), pd.Series(seven_day_tst), color = "blue", linewidth = 2,
            label = "Average Number of Tests")
    plt.plot(range(len(seven_day_pos)), seven_day_pos, color = "red", linewidth = 2,
            label = "Average Number of Positive Tests")
    plt.plot(range(len(seven_day_dth)), seven_day_dth, color = "black", linewidth = 2,
            label = "Average Number of Deaths")
    plt.title("Wisconsin COVID-19 7-day Moving Averages")
    plt.xlabel("Dates")
    plt.ylabel("Average Number of Cases")
    plt.legend()
    # Annotate certain key dates in the Wisconsin COVID-19 timeline
    # First date Wisconsin DHS creates a dashboard tracking cases
    plt.annotate("1",
                 xy = (0, seven_day_pos[0]),
                 xytext = (0, seven_day_pos[0] + 1000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All gatherings of more than 10 people banned
    plt.annotate("2",
                 xy = (2, seven_day_pos[2]),
                 xytext = (2, seven_day_pos[2] + 1000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All state schools close, March 18th
    plt.annotate("3",
                 xy = (3, seven_day_pos[3]),
                 xytext = (3, seven_day_pos[3] + 1000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All non-essential businesses are ordered to close, March 24th
    plt.annotate("4",
                 xy = (8, seven_day_pos[4]),
                 xytext = (8, seven_day_pos[4] + 1000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Tests from non-Wisconsin residents removed from dataset
    plt.annotate("5",
                 xy = (15, seven_day_pos[15]),
                 xytext = (15, seven_day_pos[15] + 1000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order extended to May 26th, April 16th
    plt.annotate("6",
                 xy = (31, seven_day_pos[31]),
                 xytext = (31, seven_day_pos[31] + 1000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Anti-lockdown protests at State Capitol, April 24th
    plt.annotate("7",
                  xy = (39, seven_day_pos[39]),
                  xytext = (39, seven_day_pos[39] + 1000),
                  arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order struck down by Wisconsin Supreme Court, May 13th
    plt.annotate("8",
                  xy = (57, seven_day_pos[57]),
                  xytext = (57, seven_day_pos[57] + 1000),
                  arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # George Floyd is killed by MPLS Police, May 25th
    plt.annotate("9",
                 xy = (70, seven_day_pos[70]),
                 xytext = (70, seven_day_pos[70] + 1000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # July 4th
    plt.annotate("10",
                  xy = (110, seven_day_pos[110]),
                  xytext = (110, seven_day_pos[110] + 1000),
                  arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Governor Evers declares public health emergency requiring masks to be worn
    # in enclosed spaces outside private residences, July 30th
    plt.annotate("11",
                  xy = (136, seven_day_pos[136]),
                  xytext = (136, seven_day_pos[136] + 1000),
                  arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Labor Day, September 7th. Public schools to start class or are entering their second week
    plt.annotate("12",
                 xy = (175, seven_day_pos[175]),
                 xytext = (175, seven_day_pos[175] + 1000),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    ax.set_xticks(range(len(dates)))
    ax.set_xticklabels(dates)
    for idx, lbl in enumerate(ax.get_xticklabels()):
        if idx % 14 != 0:
            lbl.set_visible(False)
    plt.xticks(rotation = 300)

# %%
plt_covid_cum(state_data["DATE"], state_data["POSITIVE"], state_data["NEGATIVE"],
                         state_data["DEATHS"])

# %% [markdown]
# #### Key Dates in Plot
# 1. March 15, 2020: First recorded COVID-19 test results on the Wisconsin Dept. of Health Services.
# 2. March 17, 2020: Governor Evers bans all gatherings of over 10 people in WI
# 3. March 18, 2020: All public and private schools to close until further notice based on March 13th order by Governor Evers
# 4. March 24, 2020: All non-essential businesses are ordered to close
# 5. March 29, 2020 - March 30, 2020: Wisconsin Department of Health Services removes cases from dataset that contained
# 5. April 16, 2020: Governor Evers extends his stay at home order for the state of Wisconsin until May 26th
# 6. April 24, 2020: Anti-lockdown protests occur at the WI State Capitol in Madison, WI
# 7. May 13, 2020: Wisconsin Supreme Court strikes down Safer-at-Home order extension; businesses start reopening and gatherings allowed
# 8. May 26, 2020: George Floyd is killed by Minneappolis Police Officer Derek Chauvin; Chauvin was fired and charged with murder
# 9. July 4, 2020: National holiday
# 10. July 30, 2020: Governor Evers issues public health emergency and issues order requiring masks in all enclosed spaces outside of private residences
# 11. September 7, 2020: Labor Day; most Wisconsin public schools begin school this week or are entering their 2nd week of instruction

# %%
plt_positive_percentage(state_data["DATE"], state_data["POS_NEW"], state_data["TEST_NEW"])

# %% [markdown]
# #### Key Dates in Plot
# 1. March 15, 2020: First recorded COVID-19 test results on the Wisconsin Dept. of Health Services.
# 2. March 17, 2020: Governor Evers bans all gatherings of over 10 people in WI
# 3. March 18, 2020: All public and private schools to close until further notice based on March 13th order by Governor Evers
# 4. March 24, 2020: All non-essential businesses are ordered to close
# 5. March 29-30, 2020: Wisconsin Deptartment of Health Services removes records of cases from database from non-Wisconsin residents.
# 6. April 16, 2020: Governor Evers extends his stay at home order for the state of Wisconsin until May 26th
# 7. April 24, 2020: Anti-lockdown protests occur at the WI State Capitol in Madison, WI
# 8. May 13, 2020: Wisconsin Supreme Court strikes down Safer-at-Home order extension; businesses start reopening and gatherings allowed
# 9. May 26, 2020: George Floyd is killed by Minneappolis Police Officer Derek Chauvin; Chauvin was fired and charged with murder
# 10. July 4, 2020: National holiday
# 11. July 30, 2020: Governor Evers issues public health emergency and issues order requiring masks in all enclosed spaces outside of private residences
# 12. September 7, 2020: Labor Day; most Wisconsin public schools begin school this week or are entering their 2nd week of instruction

# %%
plt_seven_day(dates = state_data["DATE"][7:], 
              new_pos = state_data["POS_NEW"], 
              new_tests = state_data["TEST_NEW"], 
              new_dth = state_data["DTH_NEW"])

# %% [markdown]
# #### Key Dates in Plot
# 1. March 15, 2020: First recorded COVID-19 test results on the Wisconsin Dept. of Health Services.
# 2. March 17, 2020: Governor Evers bans all gatherings of over 10 people in WI
# 3. March 18, 2020: All public and private schools to close until further notice based on March 13th order by Governor Evers
# 4. March 24, 2020: All non-essential businesses are ordered to close
# 5. April 16, 2020: Governor Evers extends his stay at home order for the state of Wisconsin until May 26th
# 6. April 24, 2020: Anti-lockdown protests occur at the WI State Capitol in Madison, WI
# 7. May 13, 2020: Wisconsin Supreme Court strikes down Safer-at-Home order extension; businesses start reopening and gatherings allowed
# 8. May 26, 2020: George Floyd is killed by Minneappolis Police Officer Derek Chauvin; Chauvin was fired and charged with murder
# 9. July 4, 2020: National holiday
# 10. July 30, 2020: Governor Evers issues public health emergency and issues order requiring masks in all enclosed spaces outside of private residences
# 11. September 7, 2020: Labor Day; most Wisconsin public schools begin school this week or are entering their 2nd week of instruction
#
# #### Graphing comparisons between racial groups and age groups
#
# We want to look at differences between infection rates and hospitalizations between different demograhpic groups. This can include, but is not limited to:
# - Racial and ethnic differences
# - Age discrepencies
# - Gender disparities

# %% [markdown]
# ```python
# # Make cell a Python code cell by hitting ESC-y; make markdown again by hitting ESC-m
# for col in state_data.columns:
#     print(col)
# ```

# %%
# We start by gathering the cummulative positive tests, deaths,
# unknown hospializations, confirmed hospitalizations, and intensive care cases.
ages_0_9   = state_data[["DATE", "POS_0_9", "DTHS_0_9", "IP_Y_0_9", "IP_U_0_9", "IC_Y_0_9"]].fillna(0)
ages_10_19 = state_data[["DATE", "POS_10_19", "DTHS_10_19", "IP_Y_10_19", "IP_U_10_19", "IC_Y_10_19"]].fillna(0)
ages_20_29 = state_data[["DATE", "POS_20_29", "DTHS_20_29", "IP_Y_20_29", "IP_U_20_29", "IC_Y_20_29"]].fillna(0)
ages_30_39 = state_data[["DATE", "POS_30_39", "DTHS_30_39", "IP_Y_30_39", "IP_U_30_39", "IC_Y_30_39"]].fillna(0)
ages_40_49 = state_data[["DATE", "POS_40_49", "DTHS_40_49", "IP_Y_40_49", "IP_U_40_49", "IC_Y_40_49"]].fillna(0)
ages_50_59 = state_data[["DATE", "POS_50_59", "DTHS_50_59", "IP_Y_50_59", "IP_U_50_59", "IC_Y_50_59"]].fillna(0)
ages_60_69 = state_data[["DATE", "POS_60_69", "DTHS_60_69", "IP_Y_60_69", "IP_U_60_69", "IC_Y_60_69"]].fillna(0)
ages_70_79 = state_data[["DATE", "POS_70_79", "DTHS_70_79", "IP_Y_70_79", "IP_U_70_79", "IC_Y_70_79"]].fillna(0)
ages_80_89 = state_data[["DATE", "POS_80_89", "DTHS_80_89", "IP_Y_80_89", "IP_U_80_89", "IC_Y_80_89"]].fillna(0)
ages_90 = state_data[["DATE", "POS_90", "DTHS_90", "IP_Y_90", "IP_U_90", "IC_Y_90"]].fillna(0)

# %%
def plt_testing_chars(ages_0_9, ages_10_19, ages_20_29, ages_30_39, ages_40_49, ages_50_59,
                 ages_60_69, ages_70_79, ages_80_89, ages_90, dates, title, ylabel, arrow_adj):
    """
    plt_age_chars is meant to plot the different levels of tests, hospitalizations, deaths, etc.
    among different age groups in WI.
    """
    plt.figure(figsize = (12, 8))
    ax = plt.subplot()
    plt.plot(range(len(dates)), ages_0_9, color = "tab:blue", linewidth = 1.5, label = "Ages 0 to 9")
    plt.plot(range(len(dates)), ages_10_19, color = "tab:orange", linewidth = 1.5, label = "Ages 10 to 19")
    plt.plot(range(len(dates)), ages_20_29, color = "tab:green", linewidth = 1.5, label = "Ages 20 to 29")
    plt.plot(range(len(dates)), ages_30_39, color = "tab:red", linewidth = 1.5, label = "Ages 30 to 39")
    plt.plot(range(len(dates)), ages_40_49, color = "tab:purple", linewidth = 1.5, label = "Ages 40 to 49")
    plt.plot(range(len(dates)), ages_50_59, color = "tab:brown", linewidth = 1.5, label = "Ages 50 to 59")
    plt.plot(range(len(dates)), ages_60_69, color = "tab:pink", linewidth = 1.5, label = "Ages 60 to 69")
    plt.plot(range(len(dates)), ages_70_79, color = "tab:gray", linewidth = 1.5, label = "Ages 70 to 79")
    plt.plot(range(len(dates)), ages_80_89, color = "tab:olive", linewidth = 1.5, label = "Ages 80 to 89")
    plt.plot(range(len(dates)), ages_90, color = "tab:cyan", linewidth =1.5, label = "Ages 90 and over")
    plt.legend()
    # Adding in plot labels
    plt.title(title)
    plt.ylabel(ylabel)
    
    plt.annotate("1",
                 xy = (0, ages_20_29[0]),
                 xytext = (0, ages_20_29[0] + arrow_adj),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All gatherings of more than 10 people banned
    plt.annotate("2",
                 xy = (2, ages_20_29[2]),
                 xytext = (2, ages_20_29[2] + arrow_adj),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All state schools close, March 18th
    plt.annotate("3",
                 xy = (5, ages_20_29[3]),
                 xytext = (5, ages_20_29[3] + arrow_adj),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All non-essential businesses are ordered to close, March 24th
    plt.annotate("4",
                xy = (8, ages_20_29[4]),
                xytext = (8, ages_20_29[4] + arrow_adj),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # State deletes all non-Wisconsin resident tests from their dashboard
    plt.annotate("5",
                xy = (15, ages_20_29[15]),
                xytext = (15, ages_20_29[15] + arrow_adj),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order extended to May 26th, April 16th
    plt.annotate("6",
                xy = (31, ages_20_29[31]),
                xytext = (31, ages_20_29[31] + arrow_adj),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Anti-lockdown protests at State Capitol, April 24th
    plt.annotate("7",
                 xy = (39, ages_20_29[39]),
                 xytext = (39, ages_20_29[39] + arrow_adj),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order struck down by Wisconsin Supreme Court, May 13th
    plt.annotate("8",
                 xy = (57, ages_20_29[57]),
                 xytext = (57, ages_20_29[57] + arrow_adj),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # George Floyd is killed by MPLS Police, May 25th
    plt.annotate("9",
                xy = (70, ages_20_29[70]),
                xytext = (70, ages_20_29[70] + arrow_adj),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # July 4th
    plt.annotate("10",
                 xy = (110, ages_20_29[110]),
                 xytext = (110, ages_20_29[110] + arrow_adj),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Governor Evers declares public health emergency requiring masks to be worn
    # in enclosed spaces outside private residences, July 30th
    plt.annotate("11",
                 xy = (136, ages_20_29[136]),
                 xytext = (136, ages_20_29[136] + arrow_adj),
                 arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Labor Day, September 7th. Public schools to start class or are entering their second week
    plt.annotate("12",
                xy = (175, ages_20_29[175]),
                xytext = (175, ages_20_29[175] + arrow_adj),
                arrowprops = dict(facecolor = 'black', shrink = 0.05))
    plt.xlabel("Date")
    ax.set_xticks(range(len(dates)))
    ax.set_xticklabels(dates)
    # TO-DO: add xticks for every week
    for idx, lbl in enumerate(ax.get_xticklabels()):
        if idx % 14 != 0:
            lbl.set_visible(False)
    plt.xticks(rotation = 300)

# %%
plt_testing_chars(ages_0_9.POS_0_9, ages_10_19.POS_10_19, ages_20_29.POS_20_29,
                  ages_30_39.POS_30_39, ages_40_49.POS_40_49, ages_50_59.POS_50_59, ages_60_69.POS_60_69,
                  ages_70_79.POS_70_79, ages_80_89.POS_80_89, ages_90.POS_90, state_data.DATE,
                  title = "Positive Tests Amongst Different Age Demographics in Wisconsin",
                  ylabel = "Cummulative Count of Positive Cases",
                  arrow_adj = 5000)

# %% [markdown]
# #### Key Dates in Plot
# 1. March 15, 2020: First recorded COVID-19 test results on the Wisconsin Dept. of Health Services.
# 2. March 17, 2020: Governor Evers bans all gatherings of over 10 people in WI
# 3. March 18, 2020: All public and private schools to close until further notice based on March 13th order by Governor Evers
# 4. March 24, 2020: All non-essential businesses are ordered to close
# 5. March 29-30, 2020: Wisconsin Deptartment of Health Services removes records of cases from database from non-Wisconsin residents.
# 6. April 16, 2020: Governor Evers extends his stay at home order for the state of Wisconsin until May 26th
# 7. April 24, 2020: Anti-lockdown protests occur at the WI State Capitol in Madison, WI
# 8. May 13, 2020: Wisconsin Supreme Court strikes down Safer-at-Home order extension; businesses start reopening and gatherings allowed
# 9. May 26, 2020: George Floyd is killed by Minneappolis Police Officer Derek Chauvin; Chauvin was fired and charged with murder
# 10. July 4, 2020: National holiday
# 11. July 30, 2020: Governor Evers issues public health emergency and issues order requiring masks in all enclosed spaces outside of private residences
# 12. September 7, 2020: Labor Day; most Wisconsin public schools begin school this week or are entering their 2nd week of instruction

# %%
plt_testing_chars(ages_0_9.IP_Y_0_9, ages_10_19.IP_Y_10_19, ages_20_29.IP_Y_20_29,
                  ages_30_39.IP_Y_30_39, ages_40_49.IP_Y_40_49, ages_50_59.IP_Y_50_59, ages_60_69.IP_Y_60_69,
                  ages_70_79.IP_Y_70_79, ages_80_89.IP_Y_80_89, ages_90.IP_Y_90, state_data.DATE,
                  title = "Known Hospitalizations Amongst Different Age Demographics in Wisconsin",
                  ylabel = "Cummulative Count of Hospitalizations Cases",
                  arrow_adj = 150)

# %%
plt_testing_chars(ages_0_9.IC_Y_0_9, ages_10_19.IC_Y_10_19, ages_20_29.IC_Y_20_29,
                  ages_30_39.IC_Y_30_39, ages_40_49.IC_Y_40_49, ages_50_59.IC_Y_50_59, ages_60_69.IC_Y_60_69,
                  ages_70_79.IC_Y_70_79, ages_80_89.IC_Y_80_89, ages_90.IC_Y_90, state_data.DATE,
                  title = "COVID-19 Patients in Intensive Care \n Amongst Different Age Demographics in Wisconsin",
                  ylabel = "Cummulative Count of COVID Patients Who Went to ICU",
                  arrow_adj = 25)

# %% [markdown]
# After looking at the cummulative statistics of COVID-19 related key events in the timeline of the infection, we should start looking at the daily rates and take a moving average over these statistics.

# %%
def daily_infection_rates_ages(total, ages_0_9, ages_10_19, ages_20_29, ages_30_39, ages_40_49, ages_50_59,
                 ages_60_69, ages_70_79, ages_80_89, ages_90, dates, title1, title2, ylabel, arrow_adj = 0):
    # Calculate and plot the daily increase/decrease in infections, hospitalizations, ICU patients
    daily_0_9   = pd.Series(ages_0_9).diff()
    daily_10_19 = pd.Series(ages_10_19).diff()
    daily_20_29 = pd.Series(ages_20_29).diff()
    daily_30_39 = pd.Series(ages_30_39).diff()
    daily_40_49 = pd.Series(ages_40_49).diff()
    daily_50_59 = pd.Series(ages_50_59).diff()
    daily_60_69 = pd.Series(ages_60_69).diff()
    daily_70_79 = pd.Series(ages_70_79).diff()
    daily_80_89 = pd.Series(ages_80_89).diff()
    daily_90    = pd.Series(ages_90).diff()
    daily_0_9[0] = 0; daily_10_19[0] = 0; daily_20_29[0] = 0; daily_30_39[0] = 0; daily_40_49[0] = 0
    daily_50_59[0] = 0; daily_60_69[0] = 0; daily_70_79[0] = 0; daily_80_89[0] = 0; daily_90[0] = 0
    # Plot these demographic pieces of information
    daily_nir = {
        'a09': np.zeros(len(ages_0_9)),
        'a1019': np.zeros(len(ages_10_19)),
        'a2029': np.zeros(len(ages_20_29)),
        'a3039': np.zeros(len(ages_30_39)),
        'a4049': np.zeros(len(ages_40_49)),
        'a5059': np.zeros(len(ages_50_59)),
        'a6069': np.zeros(len(ages_60_69)),
        'a7079': np.zeros(len(ages_70_79)),
        'a8089': np.zeros(len(ages_80_89)),
        'a90': np.zeros(len(ages_90)),
        'dates': dates
    }
    seven_day = pd.DataFrame(daily_nir)
    for i in range(len(daily_0_9[:6]), len(daily_0_9)):
        seven_day.a09[i] = (np.sum(np.array(daily_0_9[i:(i+7)]).astype(float)) / 7.)
        seven_day.a1019[i] = (np.sum(np.array(daily_10_19[i:(i+7)]).astype(float)) / 7.)
        seven_day.a2029[i] = (np.sum(np.array(daily_20_29[i:(i+7)]).astype(float)) / 7.)
        seven_day.a3039[i] = (np.sum(np.array(daily_30_39[i:(i+7)]).astype(float)) / 7.)
        seven_day.a4049[i] = (np.sum(np.array(daily_40_49[i:(i+7)]).astype(float)) / 7.)
        seven_day.a5059[i] = (np.sum(np.array(daily_50_59[i:(i+7)]).astype(float)) / 7.)
        seven_day.a6069[i] = (np.sum(np.array(daily_60_69[i:(i+7)]).astype(float)) / 7.)
        seven_day.a7079[i] = (np.sum(np.array(daily_70_79[i:(i+7)]).astype(float)) / 7.)
        seven_day.a8089[i] = (np.sum(np.array(daily_80_89[i:(i+7)]).astype(float)) / 7.)
        seven_day.a90[i] = (np.sum(np.array(daily_90[i:(i+7)]).astype(float)) / 7.)
    # Plot these seven-day infection rates and the moving averages
    colors = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple",
             "tab:brown", "tab:pink", "tab:gray", "tab:olive", "tab:cyan"]
    
    plt.figure(figsize = (12, 16))
    ax1 = plt.subplot(211)
    ax1.bar(range(len(daily_0_9)), daily_0_9, width = 0.5, color = colors[0], label = "Ages 0-9")
    ax1.bar(range(len(daily_10_19)), daily_10_19, width = 0.5, bottom = daily_0_9, color = colors[1], label = "Ages 10-19")
    ax1.bar(range(len(daily_20_29)), daily_20_29, width = 0.5, bottom = daily_10_19, color = colors[2], label = "Ages 20-29")
    ax1.bar(range(len(daily_30_39)), daily_30_39, width = 0.5, bottom = daily_20_29, color = colors[3], label = "Ages 30-39")
    ax1.bar(range(len(daily_40_49)), daily_40_49, width = 0.5, bottom = daily_30_39, color = colors[4], label = "Ages 40-49")
    ax1.bar(range(len(daily_50_59)), daily_50_59, width = 0.5, bottom = daily_40_49, color = colors[5], label = "Ages 50-59")
    ax1.bar(range(len(daily_60_69)), daily_60_69, width = 0.5, bottom = daily_50_59, color = colors[6], label = "Ages 60-69")
    ax1.bar(range(len(daily_70_79)), daily_70_79, width = 0.5, bottom = daily_60_69, color = colors[7], label = "Ages 70-79")
    ax1.bar(range(len(daily_80_89)), daily_80_89, width = 0.5, bottom = daily_70_79, color = colors[8], label = "Ages 80-89")
    ax1.bar(range(len(daily_90)), daily_90, width = 0.5, bottom = daily_80_89, color = colors[9], label = "Ages 90 and Over")
    ax1.legend()
    ax1.set_xlabel("Date")
    ax1.set_ylabel(ylabel)
    ax1.set_title(title1)
    # Annotate certain key dates in the Wisconsin COVID-19 timeline
    # First date Wisconsin DHS creates a dashboard tracking cases
    #ax1.annotate("1",
    #             xy = (0, total[0]),
    #             xytext = (0, total[0] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All gatherings of more than 10 people banned
    #ax1.annotate("2",
    #             xy = (2, total[2]),
    #             xytext = (2, total[2] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All state schools close, March 18th
    #ax1.annotate("3",
    #             xy = (5, total[3]),
    #             xytext = (5, total[3] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All non-essential businesses are ordered to close, March 24th
    #ax1.annotate("4",
    #            xy = (8, total[8]),
    #            xytext = (8, total[8] + arrow_adj),
    #            arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order extended to May 26th, April 16th
    #ax1.annotate("5",
    #            xy = (31, total[31]),
    #            xytext = (31, total[31] + arrow_adj),
    #            arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Anti-lockdown protests at State Capitol, April 24th
    #ax1.annotate("6",
    #             xy = (39, total[39]),
    #             xytext = (39, total[39] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order struck down by Wisconsin Supreme Court, May 13th
    #ax1.annotate("7",
    #             xy = (57, total[57]),
    #             xytext = (57, total[57] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # George Floyd is killed by MPLS Police, May 25th
    #ax1.annotate("8",
    #            xy = (70, total[70]),
    #            xytext = (70, total[70] + arrow_adj),
    #            arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # July 4th
    #ax1.annotate("9",
    #             xy = (110, total[110]),
    #             xytext = (110, total[110] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Governor Evers declares public health emergency requiring masks to be worn
    # in enclosed spaces outside private residences, July 30th
    #ax1.annotate("10",
    #             xy = (136, total[136]),
    #             xytext = (136, total[136] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Labor Day, September 7th. Public schools to start class or are entering their second week
    #ax1.annotate("11",
    #            xy = (175, total[175]),
    #            xytext = (175, total[175] + arrow_adj),
    #            arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # TO-DO: add xticks for every week
    ax1.set_xticks(range(len(daily_0_9)))
    ax1.set_xticklabels(dates, rotation = 300)
    # TO-DO: add xticks for every week
    for idx, lbl in enumerate(ax1.get_xticklabels()):
        if idx % 14 != 0:
            lbl.set_visible(False)
            
    ax2 = plt.subplot(212)
    ax2.bar(range(len(seven_day.a09)), seven_day.a09, width = 0.5,
            color = colors[0], label = "Ages 0-9")
    ax2.bar(range(len(seven_day.a1019)), seven_day.a1019, width = 0.5,
            bottom = seven_day.a09, color = colors[1], label = "Ages 10-19")
    ax2.bar(range(len(seven_day.a2029)), seven_day.a2029, width = 0.5,
            bottom = seven_day.a1019, color = colors[2], label = "Ages 20-29")
    ax2.bar(range(len(seven_day.a3039)), seven_day.a3039, width = 0.5,
            bottom = seven_day.a2029, color = colors[3], label = "Ages 30-39")
    ax2.bar(range(len(seven_day.a4049)), seven_day.a4049, width = 0.5,
            bottom = seven_day.a3039, color = colors[4], label = "Ages 40-49")
    ax2.bar(range(len(seven_day.a5059)), seven_day.a5059, width = 0.5,
            bottom = seven_day.a4049, color = colors[5], label = "Ages 50-59")
    ax2.bar(range(len(seven_day.a6069)), seven_day.a6069, width = 0.5,
            bottom = seven_day.a5059, color = colors[6], label = "Ages 60-69")
    ax2.bar(range(len(seven_day.a7079)), seven_day.a7079, width = 0.5,
            bottom = seven_day.a6069, color = colors[7], label = "Ages 70-79")
    ax2.bar(range(len(seven_day.a8089)), seven_day.a8089, width = 0.5,
            bottom = seven_day.a7079, color = colors[8], label = "Ages 80-89")
    ax2.bar(range(len(seven_day.a90)), seven_day.a90, width = 0.5,
            bottom = seven_day.a8089, color = colors[9], label = "Ages 90 and Over")
    ax2.legend()
    ax2.set_xlabel("Date")
    ax2.set_ylabel(ylabel)
    ax2.set_title(title2)
    # Annotate certain key dates in the Wisconsin COVID-19 timeline
    # First date Wisconsin DHS creates a dashboard tracking cases
    #ax2.annotate("1",
    #             xy = (0, total[0]),
    #             xytext = (0, total[0] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All gatherings of more than 10 people banned
    #ax2.annotate("2",
    #             xy = (2, total[2]),
    #             xytext = (2, total[2] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All state schools close, March 18th
    #ax2.annotate("3",
    #             xy = (5, total[3]),
    #             xytext = (5, total[3] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # All non-essential businesses are ordered to close, March 24th
    #ax2.annotate("4",
    #            xy = (8, total[8]),
    #            xytext = (8, total[8] + arrow_adj),
    #            arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order extended to May 26th, April 16th
    #ax2.annotate("5",
    #            xy = (31, total[31]),
    #            xytext = (31, total[31] + arrow_adj),
    #            arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Anti-lockdown protests at State Capitol, April 24th
    #ax2.annotate("6",
    #             xy = (39, total[39]),
    #             xytext = (39, total[39] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Safer-at-home order struck down by Wisconsin Supreme Court, May 13th
    #ax2.annotate("7",
    #             xy = (57, total[57]),
    #             xytext = (57, total[57] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # George Floyd is killed by MPLS Police, May 25th
    #ax2.annotate("8",
    #            xy = (70, total[70]),
    #            xytext = (70, total[70] + arrow_adj),
    #            arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # July 4th
    #ax2.annotate("9",
    #             xy = (110, total[110]),
    #             xytext = (110, total[110] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Governor Evers declares public health emergency requiring masks to be worn
    # in enclosed spaces outside private residences, July 30th
    #ax2.annotate("10",
    #             xy = (136, total[136]),
    #             xytext = (136, total[136] + arrow_adj),
    #             arrowprops = dict(facecolor = 'black', shrink = 0.05))
    # Labor Day, September 7th. Public schools to start class or are entering their second week
    #ax2.annotate("11",
    #            xy = (175, total[175]),
    #            xytext = (175, total[175] + arrow_adj),
    #            arrowprops = dict(facecolor = 'black', shrink = 0.05))
    ax2.set_xticks(range(len(daily_0_9)))
    ax2.set_xticklabels(dates, rotation = 300)
    # TO-DO: add xticks for every week
    for idx, lbl in enumerate(ax2.get_xticklabels()):
        if idx % 14 != 0:
            lbl.set_visible(False)
    plt.subplots_adjust(hspace = 0.5)

# %%
daily_infection_rates_ages(total = state_data.POS_NEW, ages_0_9 = state_data.POS_0_9, 
                           ages_10_19=state_data.POS_10_19, ages_20_29=state_data.POS_20_29,
                           ages_30_39=state_data.POS_30_39, ages_40_49=state_data.POS_40_49,
                           ages_50_59=state_data.POS_50_59, ages_60_69=state_data.POS_60_69,
                           ages_70_79=state_data.POS_70_79, ages_80_89=state_data.POS_80_89,
                           ages_90=state_data.POS_90, dates = state_data.DATE,
                           title1 = "Daily Count of New Infections by Age Group",
                           title2 = "7-day Moving Average of New Infections by Age Group",
                           ylabel = "Daily New Infections", arrow_adj = 100)

# %%
# The last 2 months of data are of utmost interest to me, so we will look at the plots going back 60 days
l60d = {
    "pos_new": np.array(state_data.POS_NEW[-60:]),
    "a09": np.array(state_data.POS_0_9[-60:]),
    "a1019": np.array(state_data.POS_10_19[-60:]),
    "a2029": np.array(state_data.POS_20_29[-60:]),
    "a3039": np.array(state_data.POS_30_39[-60:]),
    "a4049": np.array(state_data.POS_40_49[-60:]),
    "a5059": np.array(state_data.POS_50_59[-60:]),
    "a6069": np.array(state_data.POS_60_69[-60:]),
    "a7079": np.array(state_data.POS_70_79[-60:]),
    "a8089": np.array(state_data.POS_80_89[-60:]),
    "a90": np.array(state_data.POS_90[-60:]),
    "dates": state_data.DATE[-60:],
}

last_60_days = pd.DataFrame(l60d).reset_index()

daily_infection_rates_ages(total=last_60_days.pos_new,
                           ages_0_9=last_60_days.a09,
                           ages_10_19=last_60_days.a1019,
                           ages_20_29=last_60_days.a2029,
                           ages_30_39=last_60_days.a3039,
                           ages_40_49=last_60_days.a4049,
                           ages_50_59=last_60_days.a5059,
                           ages_60_69=last_60_days.a6069,
                           ages_70_79=last_60_days.a7079,
                           ages_80_89=last_60_days.a8089,
                           ages_90=last_60_days.a90,
                           dates=last_60_days.dates,
                           title1 = "Daily Count of New Infections by Age Group \n Since August 1, 2020",
                           title2 = "7-day Moving Average of New Infections by Age Group \n Since August 1, 2020",
                           ylabel = "Daily New Infections", arrow_adj = 100)

# %%
daily_infection_rates_ages(total = state_data.HOSP_YES, ages_0_9 = state_data.IP_Y_0_9, 
                           ages_10_19=state_data.IP_Y_10_19, ages_20_29=state_data.IP_Y_20_29,
                           ages_30_39=state_data.IP_Y_30_39, ages_40_49=state_data.IP_Y_40_49,
                           ages_50_59=state_data.IP_Y_50_59, ages_60_69=state_data.IP_Y_60_69,
                           ages_70_79=state_data.IP_Y_70_79, ages_80_89=state_data.IP_Y_80_89,
                           ages_90=state_data.IP_Y_90, dates = state_data.DATE,
                           title1 = "Daily Count of New Hospitalizations by Age Group",
                           title2 = "7-day Moving Average of New Hospitalizations by Age Group",
                           ylabel = "Daily New Hospitalizations", arrow_adj = 100)

# %%
daily_infection_rates_ages(total = state_data.IC_YES, ages_0_9 = state_data.IC_Y_0_9, 
                           ages_10_19=state_data.IC_Y_10_19, ages_20_29=state_data.IC_Y_20_29,
                           ages_30_39=state_data.IC_Y_30_39, ages_40_49=state_data.IC_Y_40_49,
                           ages_50_59=state_data.IC_Y_50_59, ages_60_69=state_data.IC_Y_60_69,
                           ages_70_79=state_data.IC_Y_70_79, ages_80_89=state_data.IC_Y_80_89,
                           ages_90=state_data.IC_Y_90, dates = state_data.DATE,
                           title1 = "Daily Count of Change in COVID-Related Intensive Care Patients \n by Age Group",
                           title2 = "7-day Moving Average of Change in COVID-Related Intensive Care Patients \n by Age Group",
                           ylabel = "Daily Change in Patients", arrow_adj = 100)
